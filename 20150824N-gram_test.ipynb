# %%
import codecs
import operator
import os

cutlist = " <>/:：;；,、＂’，.。！？｢\"\'\\\n\r《》“”!@#$%^&*()".decode("utf-8")  ##列出標點符號，並轉換成utf-8的格式

def cutSentence(text_path, keywords): ##放入原始文章路徑, 增加斷詞的list
    text = codecs.open(text_path,"r","UTF-8",errors='ignore')   #開檔
    sentence = ""
    textList = []
       
    for line in text.read():
        line = line.strip() ##清除空白
        #line = line.replace(' ', '')
        
        for keyword in keywords:  #清除關鍵字
            line = "".join(line.split(keyword))

        for word in line:
            if word not in cutlist: #如果文字不是標點符號，就把字加到句子中
                sentence += word
                #print sentence
            else:
                textList.append(sentence) #把文章句子依標點符號與空白隔開
                sentence = ""
            #for ele in textList: #顯示文章所斷句子
                #print ele
    return textList
    
def ngram(textLists,n,minFreq): 
    #首參數放處理好的文章(LIST檔，utf-8編碼)次參數放字詞的長度單位，第三個參數放多少頻次以上
    words=[]     #存放擷取出來的字詞
    words_freq={}#存放字詞:計算個數 
    result= []
    for textList in textLists:
        for w in range(len(textList)-(n-1)): #要讀取的長度隨字詞長度改變
            words.append(textList[w:w+n])    #抓取長度w-(n-1)的字串

    for word in words:
        if word not in words_freq:               #如果這個字詞還沒有被放在字典檔中
            words_freq[word] = words.count(word) #就開一個新的字詞，裡面放入字詞計算的頻次
 
    words_freq = sorted(words_freq.iteritems(),key=operator.itemgetter(1),reverse=True) #change words_freq from dict to list 
    
    for word in words_freq:
        if word[1] >= minFreq:
            result.append(word)
    return result ##回傳一個陣列[詞,頻次]

def longTermPriority(path, maxTermLength, minFreq):   #目前設定只傳回長詞longTerms
    longTerms=[]          #長詞
    longTermsFreq=[]      #長詞+次數分配
    
    for i in range(maxTermLength,1,-1): ##字詞數由大至小
        text_list = cutSentence(path,longTerms)  
        #print len(text_list)
        words_freq = ngram(text_list,i, minFreq) 
        #print i

    
        for word_freq in words_freq:
            longTerms.append(word_freq[0])  
#將跑出來的長詞加入 longTerms list 做為下次切割檔案的基礎
            #print word_freq[0]
            longTermsFreq.append(word_freq) 
#將長詞和次數加入另外一個list  分成兩個檔儲存的用意是減少迴圈次數
            #print word_freq
    
    #return longTermsFreq
    return longTerms

#print os.getcwd()

longTermFreq = longTermPriority("n_gram_test.txt",7,1) ##最長詞7個字、出現頻次1次以上
#文章範例可見最下

#for i in longTermFreq:
    #print i[0],i[1]

for ele in longTermFreq:
    print ele              #印出斷字結果 


'''
longTermFreq_str = " ".join(longTermFreq)
f=open("n_gram_test"+"_2.txt","w")
f.write(longTermFreq_str.encode('utf8'))
f.close()
#print longTermFreq_str    #將斷字字串化
'''
# Out:
# 母講話也不禮貌
# 即大陸地區人民
# 照片8張等件為
# 年6月23日與
# 訊照片8張等件
# 依民法第105
# 其過失又在被告
# 1月3日完成結
# 不斷的發生爭吵
# 於99年11月
# 100年3月1
# 民法第1052
# 很多名義跟原告
# 4日出境返回大
# 造之婚姻關係已
# 原告之主觀意思
# 居住於新竹市○
# 月3日完成結婚
# 告於100年3
# 離婚協議書寄至
# 被告常用很多名
# 明人口案件登記
# 求判准兩造離婚
# 19日不告而離
# 陸地區人民行方
# 專勤隊受理外僑
# 協議書寄至大陸
# 0年10月跑回
# 路432巷7號
# 意遺棄原告之主
# 住於新竹市○區
# 原告的父母講話
# 及移民署專勤事
# 父母講話也不禮
# 涎於民國（下同
# 的父母講話也不
# 姻關係已難以維
# 方不明人口案件
# 告因而對被告提
# 後與原告口角不
# 遺棄原告之主觀
# 23日與被告即
# 052條第1項
# 年11月3日完
# 被告於100年
# 後隨即出境返回
# 同居住於新竹市
# 同年3月24日
# 6月23日與被
# 案件登記表影本
# 告就又不告而離
# 雙方共同生活中
# 告收到後又反悔
# 與原告口角不斷
# 告曾至新竹市專
# 11月3日完成
# 認兩造之婚姻關
# 3日完成結婚登
# 婚後約定共同居
# 婚姻關係已難以
# 第1052條第
# ）99年6月2
# 9年6月23日
# 棄原告之主觀意
# 婚後與原告口角
# 婚協議書寄至大
# 常用很多名義跟
# 事實足認兩造之
# 告即大陸地區人
# 將離婚協議書寄
# 知被告已經出境
# 劉昆涎於民國（
# 新竹市專勤隊受
# 關係已難以維持
# 自有惡意遺棄原
# 0月跑回來原告
# 3日與被告即大
# 告有原告家鑰匙
# 收到後又反悔說
# 有惡意遺棄原告
# 入出國及移民署
# 告的父母講話也
# 月跑回來原告家
# 而對被告提出離
# 持兩造婚姻之意
# 因而對被告提出
# 即出境返回大陸
# 簡訊照片8張等
# 市專勤隊受理外
# 民行方不明人口
# 日與被告即大陸
# 月23日與被告
# 反悔說不願離婚
# 自婚後與原告口
# 專勤隊請求協尋
# 且在繼續狀態中
# 口案件登記表影
# 事務第一大隊新
# 3月19日不告
# 昆涎於民國（下
# ...

# %%
s = '***a b   c**'
print s
s = s.replace(' ', '')
print s
s = s.replace('*', '')
print s
# Out:
# ***a b   c**
# ***abc**
# abc

# %%
'''
104053;

1040722;

離婚;

臺灣臺北地方法院民事判決　　　　　　　　104年度婚字第3號

原　　　告　于茹瑄

訴訟代理人　于姜靜妹

被　　　告　簡勝淞

上列當事人間請求離婚事件，本院於民國104年7月8日言詞辯論

終結，判決如下：

    主      文

准原告與被告離婚。

訴訟費用由被告負擔。

    事實與理由

一、被告經合法通知，未於言詞辯論期日到場，核無民事訴訟法

    第386條所列各款情形，爰依原告之聲請，由其一造辯論而

    為判決。

二、原告主張：兩造於民國95年12月10日結婚，設籍原告在臺灣

    住所，婚後分別在大陸地區華東與華南工作，由於被告負債

    累累，債權人經常到原告臺灣住所討債，對原告年邁父母造

    成嚴重困擾，而被告行蹤不明迄今逾5年，前經本院以103年

    度家婚聲字第8號裁定命被告履行同居義務確定，迄未履行

    同居，爰依民法第1052條第1項第5款規定，請判准兩造離婚

    等語。

三、按夫妻之一方於同居之訴判決確定後，仍不履行同居義務，

    在此狀態繼續存在中，而又無不能同居之正當理由者，即與

    民法第1052條第1項第5款所定之離婚要件相當，此觀最高法

    院49年臺上字第990號、第1233號判例自明。查原告就其所

    主張之事實，業據提出兩造戶籍謄本、本院103年度家婚聲

