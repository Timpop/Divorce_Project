# %% [markdown]
# ## 各地區Tf-idf挑出之關鍵字(最下)

# %% [markdown]
# #### 同義字清單

# %%
'''
re.sub(u'(酒店|嫖妓|召妓|桃色)','花酒',)
re.sub(u'(卡拉)','KTV',)
re.sub(u'(施用毒品|吸食|吸毒|吸食毒品|施用毒品)','毒品',)
re.sub(u'(建省|福建人|福建省龍|福建市|福建|福建省長)','福建省',)
re.sub(u'(鬱症)','憂鬱症',)
re.sub(u'(泰籍)','泰國藉',)
re.sub(u'(越南人|越南文|越南國)','越南',)
re.sub(u'(賭博性|賭癮|嫖賭|簽賭|賭輸|賭成性|嗜賭成性)','賭博',)
re.sub(u'(遭竊|竊錄)','竊盜',)
re.sub(u'(羞辱|毆打|毆擊|拳毆|痛毆|毆辱)','毆侮',)
re.sub(u'(酒錢|喝酒|喝醉酒|嗜酒|啤酒)','酒後',)
re.sub(u'(柬埔寨人)','柬埔寨藉',)
re.sub(u'(軍刀|水果刀|武士刀)','刀',)
re.sub(u'(打麻將)','麻將',)
re.sub(u'(染性病)','性病',)
re.sub(u'(傳宗|生子女)','傳宗接代',)
re.sub(u'(馬來西亞國|馬來西亞人)','馬來西亞',)
re.sub(u'(駐馬店市驛)','駐馬店市',)
re.sub(u'(印尼籍人|印尼文|印度尼西亞)','印尼',)
re.sub(u'(上校|中尉|軍職|國軍|少將)','軍人',)
re.sub(u'(棄夫)','拋夫棄子',)
re.sub(u'(臺大)','台大',)
re.sub(u'(msn)','MSN',)
re.sub(u'(曼谷市)','曼谷',)
re.sub(u'(人通姦)','通姦',)
re.sub(u'(波蘭商)','波蘭',)
re.sub(u'(新加坡幣|坡幣)','新加坡',)
re.sub(u'(韓國商)','韓國',)
re.sub(u'(戒指)','鑽戒',)
'''

# %%
import glob,codecs,re,jieba
filetent=[]
filelist=[]
for filename in glob.glob('E:\\iii_DataSet\\Case\\sinicut_location\\*.txt'):       
    with codecs.open( filename ,'r' ,'utf-8') as f :
        mm=re.search(r'E:\\iii_DataSet\\Case\\sinicut_location\\(\w*).txt',filename)
        casename=mm.group(1)
        worddic_file={}
        filelist.append(casename)
        content = f.read() 
        f.close()
        worddic_file={}
        content2=re.sub(u'[\s　]',';',content)
        content3=re.sub(u'[\s　\r\n]','',content2)
        for n in re.split(u';',content3):
            nn=re.split(u',',n)   
            try:
                nn1=nn[0]# word
            except:
                nn1=None
            try:
                nn2=nn[1]# Freq
            except:
                nn2=0
            worddic_file[nn1]=nn2
        file_strlist=[]
        for x in worddic_file:
            #print (x+",")*int(worddic_file[x])
            if x==None:
                xx = ""                
            else:
                xx = x+","
            file_str=''.join(xx*int(worddic_file[x]))
            file_strlist.append(file_str)
        file_str2=''.join(file_strlist) 
        file_str2_1=re.sub(u'(酒店|嫖妓|召妓|桃色)','花酒',file_str2)
        file_str2_2=re.sub(u'(卡拉)','KTV',file_str2_1.encode('utf8'))
        file_str2_3=re.sub(u'(施用毒品|吸食|吸毒|吸食毒品|施用毒品)','毒品',file_str2_2)
        file_str2_4=re.sub(u'(建省|福建人|福建省龍|福建市|福建|福建省長)','福建省',file_str2_3)
        file_str2_5=re.sub(u'(鬱症)','憂鬱症',file_str2_4)
        file_str2_6=re.sub(u'(泰籍)','泰國藉',file_str2_5)
        file_str2_7=re.sub(u'(越南人|越南文|越南國)','越南',file_str2_6)
        file_str2_8=re.sub(u'(賭博性|賭癮|嫖賭|簽賭|賭輸|賭成性|嗜賭成性)','賭博',file_str2_7)
        file_str2_9=re.sub(u'(遭竊|竊錄)','竊盜',file_str2_8)
        file_str2_10=re.sub(u'(羞辱|毆打|毆擊|拳毆|痛毆|毆辱)','毆侮',file_str2_9)
        file_str2_11=re.sub(u'(酒錢|喝酒|喝醉酒|嗜酒|啤酒)','酒後',file_str2_10)
        file_str2_12=re.sub(u'(柬埔寨人)','柬埔寨藉',file_str2_11)
        file_str2_13=re.sub(u'(軍刀|水果刀|武士刀)','刀',file_str2_12)
        file_str2_14=re.sub(u'(打麻將)','麻將',file_str2_13)
        file_str2_15=re.sub(u'(染性病)','性病',file_str2_14)
        file_str2_16=re.sub(u'(傳宗|生子女)','傳宗接代',file_str2_15)
        file_str2_17=re.sub(u'(馬來西亞國|馬來西亞人)','馬來西亞',file_str2_16)
        file_str2_18=re.sub(u'(駐馬店市驛)','駐馬店市',file_str2_17)
        file_str2_19=re.sub(u'(印尼籍人|印尼文|印度尼西亞)','印尼',file_str2_18)
        file_str2_20=re.sub(u'(上校|中尉|軍職|國軍|少將)','軍人',file_str2_19)
        file_str2_21=re.sub(u'(棄夫)','拋夫棄子',file_str2_20)
        file_str2_22=re.sub(u'(臺大)','台大',file_str2_21)
        file_str2_23=re.sub(u'(msn)','MSN',file_str2_22)
        file_str2_24=re.sub(u'(曼谷市)','曼谷',file_str2_23)
        file_str2_25=re.sub(u'(人通姦)','通姦',file_str2_24)
        file_str2_26=re.sub(u'(波蘭商)','波蘭',file_str2_25)
        file_str2_27=re.sub(u'(新加坡幣|坡幣)','新加坡',file_str2_26)
        file_str2_28=re.sub(u'(韓國商)','韓國',file_str2_27)
        file_str2_29=re.sub(u'(戒指)','鑽戒',file_str2_28)
        wd=open('E:\\iii_DataSet\\Case\\sinicut_location\\weight\\'+casename+'_str.txt','w')
        wd.write(file_str2_29)
        print file_str2_29    
        print casename
        print "-------------------------------------------------------------------"
wd.close()
# Out:
# 公婆,公婆,公婆,公婆,公婆,公婆,公婆,公婆,公婆,公婆,公婆,公婆,公婆,公婆,公婆,公婆,公婆,公婆,公婆,公婆,公婆,公婆,公婆,公婆,公婆,公婆,公婆,公婆,公婆,公婆,公婆,扶養費,扶養費,扶養費,扶養費,扶養費,扶養費,扶養費,扶養費,扶養費,扶養費,扶養費,扶養費,扶養費,扶養費,扶養費,扶養費,扶養費,扶養費,扶養費,扶養費,扶養費,扶養費,扶養費,扶養費,扶養費,扶養費,扶養費,扶養費,扶養費,聖馬爾定,聖馬爾定,聖馬爾定,聖馬爾定,聖馬爾定,聖馬爾定,聖馬爾定,聖馬爾定,聖馬爾定,聖馬爾定,聖馬爾定,聖馬爾定,聖馬爾定,聖馬爾定,聖馬爾定,聖馬爾定,聖馬爾定,聖馬爾定,聖馬爾定,毆打,毆打,毆打,毆打,毆打,毆打,毆打,毆打,毆打,毆打,毆打,毆打,毆打,毆打,毆打,毆打,毆打,毆打,毆打,毆打,毆打,毆打,毆打,毆打,毆打,毆打,毆打,毆打,毆打,毆打,毆打,毆打,毆打,毆打,毆打,毆打,毆打,毆打,毆打,毆打,毆打,毆打,毆打,毆打,毆打,毆打,毆打,毆打,毆打,毆打,毆打,毆打,毆打,毆打,毆打,毆打,毆打,毆打,毆打,毆打,毆打,毆打,毆打,毆打,毆打,毆打,毆打,毆打,毆打,毆打,毆打,毆打,毆打,毆打,毆打,毆打,毆打,毆打,毆打,毆打,毆打,毆打,毆打,毆打,毆打,毆打,毆打,毆打,毆打,毆打,毆打,毆打,毆打,毆打,毆打,毆打,毆打,毆打,毆打,毆打,毆打,毆打,毆打,毆打,毆打,毆打,毆打,毆打,毆打,毆打,毆打,毆打,毆打,毆打,毆打,毆打,毆打,毆打,毆打,毆打,毆打,毆打,毆打,毆打,毆打,毆打,毆打,毆打,毆打,毆打,毆打,毆打,毆打,毆打,毆打,毆打,毆打,毆打,毆打,毆打,毆打,毆打,毆打,毆打,毆打,毆打,毆打,毆打,毆打,毆打,毆打,毆打,毆打,毆打,毆打,毆打,毆打,毆打,毆打,毆打,毆打,毆打,毆打,毆打,毆打,毆打,毆打,毆打,毆打,毆打,毆打,毆打,毆打,毆打,毆打,毆打,毆打,毆打,毆打,毆打,毆打,毆打,毆打,毆打,毆打,毆打,毆打,毆打,毆打,毆打,毆打,毆打,毆打,毆打,毆打,毆打,毆打,毆打,毆打,毆打,毆打,毆打,毆打,毆打,毆打,毆打,毆打,毆打,毆打,毆打,毆打,毆打,毆打,毆打,毆打,毆打,毆打,毆打,毆打,毆打,毆打,毆打,毆打,毆打,毆打,毆打,毆打,毆打,毆打,毆打,毆打,毆
# ...

# %%
import glob,codecs,re,jieba
from sklearn import feature_extraction  
from sklearn.feature_extraction.text import TfidfTransformer  
from sklearn.feature_extraction.text import CountVectorizer
filetent=[]
for filename in glob.glob('E:\\iii_DataSet\\Case\\sinicut_location\\weight\\*.txt'):       
    with codecs.open( filename ,'r' ,'utf8') as f :
        mm=re.search(r'E:\\iii_DataSet\\Case\\sinicut_location\\weight\\(\w*).txt',filename)
        casename=mm.group(1)
        content=f.read()
        #print content
        f.close()
        filetent.append(content)
vectorizer=CountVectorizer(min_df=1)#该类会将文本中的词语转换为词频矩阵，矩阵元素a[i][j] 表示j
transformer=TfidfTransformer()
tfidf=transformer.fit_transform(vectorizer.fit_transform(filetent)) #corpus:欲處理文本
word=vectorizer.get_feature_names()
weight=tfidf.toarray()
for i in xrange(len(weight)):   #len(weight)=4    weight-->清單類別的特徵矩陣    
    ww=open('E:\\iii_DataSet\\Case\\sinicut_annual\\weight\\'+filelist[i]+\
                    '_weight.txt','w')
    print u"-------这里输出第",i+1,u"类文本的词语tf-idf权重------"
    for j in xrange(len(word)):
        if weight[i][j]*100 > 0:
            print word[j],"%.5f" % (weight[i][j]*100)       
            ww.write(word[j].encode('utf8')+":"+"%.5f" % (weight[i][j]*100)+"\n")
print "-------------------------------------------------------------------"
ww.close()
# Out:
# -------这里输出第 1 类文本的词语tf-idf权重------
# facebook 2.92541
# 不務正業 3.86191
# 不知去向 16.63134
# 中風 2.52764
# 債務 10.22293
# 入出國 24.75052
# 入獄 3.17205
# 入監 2.29092
# 公婆 5.46297
# 出獄 3.87695
# 出監 1.77396
# 前科 2.13877
# 勒戒 1.66540
# 升學 2.92541
# 印尼 25.45952
# 印尼國 4.70284
# 印尼籍 4.81116
# 吸毒 2.18282
# 吸食 3.70072
# 嗜酒 1.52053
# 外勞 2.29417
# 外遇 12.16330
# 娘家 37.97105
# 婆婆 9.86859
# 婆家 2.15601
# 婚外情 1.29152
# 媳婦 7.26072
# 學費 1.43734
# 家暴 2.63512
# 廣西省 2.15000
# 憂鬱症 2.72208
# 懷孕 5.46297
# 手術 4.08311
# 扶養 16.96460
# 扶養費 4.86937
# 投資 1.11027
# 拋夫棄子 1.43130
# 拳頭 1.43130
# 柬埔寨 1.84024
# 桂林市 2.15601
# 榮民 3.33080
# 毆打 42.11238
# 泰國 3.20087
# 泰國籍 2.26898
# 流產 4.73556
# 海峽 11.92156
# 瘀傷 2.08056
# 瘀血 2.91651
# 監護權 3.68048
# 福州市 2.51864
# 福建省 5.18776
# 竊取 1.22683
# 竊盜 2.33321
# 竊盜罪 1.22683
# 精神病 3.33080
# 緬甸 2.62191
# 美國 1.29531
# 聖馬爾定 9.26379
# 腦震盪 2.02738
# 自殺 4.81116
# 菜刀 2.01491
# 菲律賓 2.81960
# 虐待 27.00685
# 賭博 8.08680
# 贍養費 1.11027
# 越南 51.50097
# 越南國 4.05317
# 逃妻 3.09382
# 通姦 6.08165
# 遊手好閒 2.58303
# ...

# %%
import glob,codecs,re,_uniout
filetent=[]
for filename in glob.glob('E:\\iii_DataSet\\Case\\sinicut_annual\\weight\\*_weight.txt'):       
    with codecs.open( filename ,'r' ,'utf-8') as f :
        mm=re.search(r'E:\\iii_DataSet\\Case\\sinicut_annual\\weight\\(\w*).txt',filename)
        casename=mm.group(1)
        worddic={}
        wd=""
        wd2=""
        for line in f.readlines():
            w=re.split(r':',line.encode('utf8'))[0]
            w1=re.split(r':',line.encode('utf8'))[1]
            worddic[w]=float(w1)        
        wa=open('E:\\iii_DataSet\\Case\\sinicut_annual\\weight\\out\\'+casename+"sort.txt",'w')  
        for m in sorted(worddic,key=worddic.get,reverse=True)[:20]:
            #print m,worddic[m]
            wa.write(m+":"+str(worddic[m])+"\n")
            wd+=m+":"+str(worddic[m])+","
            wd2+=m+","
        print casename
        print wd
        print '   .........................   '
        print wd2        
        print "/////////////////////////////////////////////////////////////////"
wa.close()
f.close()
# Out:
# filter_100_weight
# 毆打:42.41518,越南:40.8032,娘家:33.44855,虐待:31.53433,債務:26.59764,外遇:23.37369,印尼:23.27294,福建省:16.52278,不知去向:15.01155,賭博:13.80256,繼承人:12.97065,美國:12.49283,扶養:11.48535,新加坡幣:11.38887,泰國:10.67936,酗酒:9.26888,海峽:9.16813,加州:8.85801,酒後:8.16064,福州市:8.05989,
#    .........................
# 毆打,越南,娘家,虐待,債務,外遇,印尼,福建省,不知去向,賭博,繼承人,美國,扶養,新加坡幣,泰國,酗酒,海峽,加州,酒後,福州市,
# /////////////////////////////////////////////////////////////////
# filter_101_weight
# 毆打:42.3745,娘家:36.78467,越南:36.69451,虐待:33.35865,扶養:30.83421,外遇:24.97391,債務:21.09709,印尼:19.74471,酗酒:14.87615,賭博:13.79425,酒後:13.16314,不知去向:12.80251,扶養費:9.75368,家暴:9.03324,婆婆:8.83553,福建省:8.74537,百度:8.49311,泰國:8.02411,美國:6.67173,監護權:5.95046,
#    .........................
# 毆打,娘家,越南,虐待,扶養,外遇,債務,印尼,酗酒,賭博,酒後,不知去向,扶養費,家暴,婆婆,福建省,百度,泰國,美國,監護權,
# /////////////////////////////////////////////////////////////////
# filter_102_weight
# ...
